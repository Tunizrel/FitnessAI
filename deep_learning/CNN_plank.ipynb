# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# (1) Training by using CNN via images

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import os
import matplotlib.pyplot as plt

# Set random seed for reproducibility
tf.keras.utils.set_random_seed(492)

# Load data from Google Drive
def import_data(base_path, class_names, img_height=224, img_width=224):
    images = []
    labels = []
    for class_idx, class_name in enumerate(class_names):
        class_folder = os.path.join(base_path, class_name)
        for img_name in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img_name)
            try:
                img = load_img(img_path, target_size=(img_height, img_width))
                img_array = img_to_array(img) / 255.0
                images.append(img_array)
                labels.append(class_idx)
            except Exception as e:
                print(f"Error loading {img_path}: {e}")
    return np.array(images), np.array(labels)

# Define CNN model
def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Plot training history
def plot_history(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'])

    plt.tight_layout()
    plt.show()

# Main
base_path = '/content/drive/My Drive/mbpose/plank'
class_names = ['Incorrect_low', 'Correct', 'Incorrect_high']
img_height, img_width = 224, 224

# Load data
x, y = import_data(base_path, class_names, img_height, img_width)
num_classes = len(np.unique(y))

# Stratified K-Fold (6 folds: 5 for validation, 1 for testing)
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)
folds = list(skf.split(x, y))

# Use last fold (fold 6) for testing
train_val_folds = folds[:-1]
test_fold = folds[-1]
x_test, y_test = x[test_fold[1]], y[test_fold[1]]

# Class weights based on training data (all 5 folds combined)
train_indices = np.concatenate([train for train, _ in train_val_folds])
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y[train_indices]), y=y[train_indices])
class_weights = {i: class_weights[i] for i in range(len(class_weights))}

precision_list, recall_list, accuracy_list, f1_list = [], [], [], []
best_fold, best_f1 = None, -1

# Train on 5 folds
for fold_index, (train_idx, val_idx) in enumerate(train_val_folds, start=1):
    x_train, x_val = x[train_idx], x[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    print(f"\nFold {fold_index} Class Distribution:")
    print(pd.Series(y_val).value_counts())

    model = create_cnn_model(input_shape=(img_height, img_width, 3), num_classes=num_classes)
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

    history = model.fit(
        x_train, y_train, epochs=30, batch_size=32,
        validation_data=(x_val, y_val), verbose=1,
        class_weight=class_weights,
        callbacks=[early_stop, reduce_lr]
    )

    plot_history(history)

    predictions = np.argmax(model.predict(x_val), axis=1)
    precision = precision_score(y_val, predictions, average='macro', zero_division=0)
    recall = recall_score(y_val, predictions, average='macro', zero_division=0)
    accuracy = accuracy_score(y_val, predictions)
    f1 = f1_score(y_val, predictions, average='macro')

    cm = confusion_matrix(y_val, predictions)
    print(f"Fold {fold_index} Confusion Matrix:")
    print(cm)

    for i, class_name in enumerate(class_names):
        class_precision = precision_score(y_val == i, predictions == i, zero_division=0)
        class_recall = recall_score(y_val == i, predictions == i, zero_division=0)
        class_f1 = f1_score(y_val == i, predictions == i, zero_division=0)
        print(f"Class {class_name}: Precision={class_precision:.4f}, Recall={class_recall:.4f}, F1={class_f1:.4f}")

    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    f1_list.append(f1)

    print(f"\n=== Fold {fold_index} ===")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")

    if f1 > best_f1:
        best_f1 = f1
        best_fold = fold_index
        best_model = model

# 5-Fold Summary
print("\n=== 5-Fold Validation Summary ===")
print(f"Avg Precision: {np.mean(precision_list):.4f}")
print(f"Avg Recall: {np.mean(recall_list):.4f}")
print(f"Avg Accuracy: {np.mean(accuracy_list):.4f}")
print(f"Avg F1 Score: {np.mean(f1_list):.4f}")
print(f"Best Fold: {best_fold} with F1 Score: {best_f1:.4f}")

# Final Test Evaluation using Fold 6
print("\n=== Final Test Fold (Fold 6) Evaluation ===")
test_predictions = np.argmax(best_model.predict(x_test), axis=1)
test_cm = confusion_matrix(y_test, test_predictions)
print(test_cm)
print("Test Accuracy: ", accuracy_score(y_test, test_predictions))
print("Test Precision:", precision_score(y_test, test_predictions, average='macro'))
print("Test Recall:   ", recall_score(y_test, test_predictions, average='macro'))
print("Test F1 Score: ", f1_score(y_test, test_predictions, average='macro'))

# Confusion matrix visualization
plt.figure(figsize=(8, 6))
plt.imshow(test_cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Test Fold 6)')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()
# Out:
# Fold 1 Class Distribution:
# 2    58
# 0    57
# 1    53
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.3674 - loss: 1.9967 - val_accuracy: 0.7262 - val_loss: 0.8204 - learning_rate: 0.0010
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.7025 - loss: 0.7058 - val_accuracy: 0.8810 - val_loss: 0.3464 - learning_rate: 0.0010
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9017 - loss: 0.2882 - val_accuracy: 0.8810 - val_loss: 0.2569 - learning_rate: 0.0010
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.9629 - loss: 0.1248 - val_accuracy: 0.9226 - val_loss: 0.2098 - learning_rate: 0.0010
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.9739 - loss: 0.0730 - val_accuracy: 0.9286 - val_loss: 0.2308 - learning_rate: 0.0010
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.9781 - loss: 0.0625 - val_accuracy: 0.9583 - val_loss: 0.1677 - learning_rate: 0.0010
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9924 - loss: 0.0330 - val_accuracy: 0.9524 - val_loss: 0.1920 - learning_rate: 0.0010
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9966 - loss: 0.0291 - val_accuracy: 0.9464 - val_loss: 0.1437 - learning_rate: 0.0010
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9989 - loss: 0.0195 - val_accuracy: 0.9583 - val_loss: 0.1397 - learning_rate: 0.0010
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9914 - loss: 0.0268 - val_accuracy: 0.9583 - val_loss: 0.1450 - learning_rate: 0.0010
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.9938 - loss: 0.0206 - val_accuracy: 0.9643 - val_loss: 0.1802 - learning_rate: 0.0010
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.9989 - loss: 0.0145 - val_accuracy: 0.9583 - val_loss: 0.1371 - learning_rate: 0.0010
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9972 - loss: 0.0099 - val_accuracy: 0.9643 - val_loss: 0.1308 - learning_rate: 0.0010
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9984 - loss: 0.0141 - val_accuracy: 0.9702 - val_loss: 0.1586 - learning_rate: 0.0010
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9926 - loss: 0.0154 - val_accuracy: 0.9345 - val_loss: 0.2229 - learning_rate: 0.0010
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9973 - loss: 0.0105 - val_accuracy: 0.9405 - val_loss: 0.2303 - learning_rate: 0.0010
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9945 - loss: 0.0096 - val_accuracy: 0.9524 - val_loss: 0.1746 - learning_rate: 5.0000e-04
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9981 - loss: 0.0091 - val_accuracy: 0.9524 - val_loss: 0.1894 - learning_rate: 5.0000e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step
# Fold 1 Confusion Matrix:
# [[55  0  2]
#  [ 0 51  2]
#  [ 0  2 56]]
# Class Incorrect_low: Precision=1.0000, Recall=0.9649, F1=0.9821
# Class Correct: Precision=0.9623, Recall=0.9623, F1=0.9623
# Class Incorrect_high: Precision=0.9333, Recall=0.9655, F1=0.9492
#
# === Fold 1 ===
# Precision: 0.9652, Recall: 0.9642, Accuracy: 0.9643, F1 Score: 0.9645
#
# Fold 2 Class Distribution:
# 2    58
# 0    57
# 1    53
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.3653 - loss: 2.2708 - val_accuracy: 0.4762 - val_loss: 1.0450 - learning_rate: 0.0010
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5947 - loss: 0.8854 - val_accuracy: 0.9048 - val_loss: 0.3712 - learning_rate: 0.0010
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.8639 - loss: 0.4016 - val_accuracy: 0.9226 - val_loss: 0.2216 - learning_rate: 0.0010
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.9383 - loss: 0.2193 - val_accuracy: 0.9524 - val_loss: 0.1493 - learning_rate: 0.0010
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.9579 - loss: 0.1168 - val_accuracy: 0.9583 - val_loss: 0.0912 - learning_rate: 0.0010
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9577 - loss: 0.0831 - val_accuracy: 0.9702 - val_loss: 0.0862 - learning_rate: 0.0010
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9771 - loss: 0.0602 - val_accuracy: 0.9643 - val_loss: 0.1528 - learning_rate: 0.0010
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9741 - loss: 0.0648 - val_accuracy: 0.9583 - val_loss: 0.2044 - learning_rate: 0.0010
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.9884 - loss: 0.0494 - val_accuracy: 0.9643 - val_loss: 0.1794 - learning_rate: 0.0010
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.9865 - loss: 0.0444 - val_accuracy: 0.9762 - val_loss: 0.1198 - learning_rate: 5.0000e-04
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9894 - loss: 0.0322 - val_accuracy: 0.9702 - val_loss: 0.1459 - learning_rate: 5.0000e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 609ms/step
# Fold 2 Confusion Matrix:
# [[54  3  0]
#  [ 0 53  0]
#  [ 0  2 56]]
# Class Incorrect_low: Precision=1.0000, Recall=0.9474, F1=0.9730
# Class Correct: Precision=0.9138, Recall=1.0000, F1=0.9550
# Class Incorrect_high: Precision=1.0000, Recall=0.9655, F1=0.9825
#
# === Fold 2 ===
# Precision: 0.9713, Recall: 0.9710, Accuracy: 0.9702, F1 Score: 0.9701
#
# Fold 3 Class Distribution:
# 2    58
# 0    57
# 1    53
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.3695 - loss: 3.6178 - val_accuracy: 0.6250 - val_loss: 0.9767 - learning_rate: 0.0010
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.6840 - loss: 0.8076 - val_accuracy: 0.8929 - val_loss: 0.4201 - learning_rate: 0.0010
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9162 - loss: 0.2888 - val_accuracy: 0.9345 - val_loss: 0.2512 - learning_rate: 0.0010
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9700 - loss: 0.0845 - val_accuracy: 0.9583 - val_loss: 0.1502 - learning_rate: 0.0010
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9890 - loss: 0.0495 - val_accuracy: 0.9583 - val_loss: 0.1325 - learning_rate: 0.0010
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9831 - loss: 0.0577 - val_accuracy: 0.9643 - val_loss: 0.1792 - learning_rate: 0.0010
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9906 - loss: 0.0289 - val_accuracy: 0.9345 - val_loss: 0.1459 - learning_rate: 0.0010
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9939 - loss: 0.0242 - val_accuracy: 0.9524 - val_loss: 0.1340 - learning_rate: 0.0010
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9937 - loss: 0.0368 - val_accuracy: 0.9583 - val_loss: 0.1686 - learning_rate: 5.0000e-04
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9942 - loss: 0.0142 - val_accuracy: 0.9583 - val_loss: 0.1687 - learning_rate: 5.0000e-04
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bfb56f3a980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 520ms/step
# Fold 3 Confusion Matrix:
# [[55  2  0]
#  [ 1 51  1]
#  [ 0  3 55]]
# Class Incorrect_low: Precision=0.9821, Recall=0.9649, F1=0.9735
# Class Correct: Precision=0.9107, Recall=0.9623, F1=0.9358
# Class Incorrect_high: Precision=0.9821, Recall=0.9483, F1=0.9649
#
# === Fold 3 ===
# Precision: 0.9583, Recall: 0.9585, Accuracy: 0.9583, F1 Score: 0.9580
#
# Fold 4 Class Distribution:
# 2    58
# 0    56
# 1    54
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.3534 - loss: 3.8551 - val_accuracy: 0.3929 - val_loss: 1.0954 - learning_rate: 0.0010
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.3950 - loss: 1.0940 - val_accuracy: 0.5060 - val_loss: 0.9618 - learning_rate: 0.0010
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.5886 - loss: 0.8656 - val_accuracy: 0.8631 - val_loss: 0.5406 - learning_rate: 0.0010
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8318 - loss: 0.4534 - val_accuracy: 0.9286 - val_loss: 0.2608 - learning_rate: 0.0010
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9139 - loss: 0.2710 - val_accuracy: 0.9167 - val_loss: 0.1990 - learning_rate: 0.0010
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9216 - loss: 0.2168 - val_accuracy: 0.9702 - val_loss: 0.1050 - learning_rate: 0.0010
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.9459 - loss: 0.1286 - val_accuracy: 0.9583 - val_loss: 0.0984 - learning_rate: 0.0010
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9734 - loss: 0.0918 - val_accuracy: 0.9762 - val_loss: 0.0895 - learning_rate: 0.0010
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9759 - loss: 0.0856 - val_accuracy: 0.9762 - val_loss: 0.0831 - learning_rate: 0.0010
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.9879 - loss: 0.0535 - val_accuracy: 0.9643 - val_loss: 0.1118 - learning_rate: 0.0010
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9808 - loss: 0.0498 - val_accuracy: 0.9881 - val_loss: 0.0547 - learning_rate: 0.0010
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.9826 - loss: 0.0464 - val_accuracy: 0.9940 - val_loss: 0.0374 - learning_rate: 0.0010
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9832 - loss: 0.0435 - val_accuracy: 0.9881 - val_loss: 0.0302 - learning_rate: 0.0010
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9897 - loss: 0.0389 - val_accuracy: 0.9702 - val_loss: 0.0579 - learning_rate: 0.0010
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9914 - loss: 0.0386 - val_accuracy: 0.9881 - val_loss: 0.0365 - learning_rate: 0.0010
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9854 - loss: 0.0491 - val_accuracy: 0.9821 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9904 - loss: 0.0466 - val_accuracy: 0.9881 - val_loss: 0.0338 - learning_rate: 5.0000e-04
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9897 - loss: 0.0397 - val_accuracy: 0.9821 - val_loss: 0.0328 - learning_rate: 5.0000e-04
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bfb57f460c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step
# Fold 4 Confusion Matrix:
# [[56  0  0]
#  [ 1 53  0]
#  [ 0  1 57]]
# Class Incorrect_low: Precision=0.9825, Recall=1.0000, F1=0.9912
# Class Correct: Precision=0.9815, Recall=0.9815, F1=0.9815
# Class Incorrect_high: Precision=1.0000, Recall=0.9828, F1=0.9913
#
# === Fold 4 ===
# Precision: 0.9880, Recall: 0.9881, Accuracy: 0.9881, F1 Score: 0.9880
#
# Fold 5 Class Distribution:
# 2    58
# 0    56
# 1    54
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.3405 - loss: 1.8736 - val_accuracy: 0.7500 - val_loss: 0.8969 - learning_rate: 0.0010
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.6946 - loss: 0.7365 - val_accuracy: 0.8750 - val_loss: 0.3697 - learning_rate: 0.0010
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9095 - loss: 0.2685 - val_accuracy: 0.9167 - val_loss: 0.2053 - learning_rate: 0.0010
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9705 - loss: 0.1126 - val_accuracy: 0.9762 - val_loss: 0.1087 - learning_rate: 0.0010
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9649 - loss: 0.1280 - val_accuracy: 0.9881 - val_loss: 0.0934 - learning_rate: 0.0010
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9806 - loss: 0.0836 - val_accuracy: 0.9940 - val_loss: 0.0663 - learning_rate: 0.0010
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 0.9912 - loss: 0.0296 - val_accuracy: 0.9821 - val_loss: 0.0702 - learning_rate: 0.0010
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9918 - loss: 0.0256 - val_accuracy: 0.9702 - val_loss: 0.0878 - learning_rate: 0.0010
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9890 - loss: 0.0605 - val_accuracy: 0.9643 - val_loss: 0.0698 - learning_rate: 0.0010
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9950 - loss: 0.0240 - val_accuracy: 0.9821 - val_loss: 0.0734 - learning_rate: 5.0000e-04
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9818 - loss: 0.0371 - val_accuracy: 0.9702 - val_loss: 0.0729 - learning_rate: 5.0000e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step
# Fold 5 Confusion Matrix:
# [[55  1  0]
#  [ 0 54  0]
#  [ 0  0 58]]
# Class Incorrect_low: Precision=1.0000, Recall=0.9821, F1=0.9910
# Class Correct: Precision=0.9818, Recall=1.0000, F1=0.9908
# Class Incorrect_high: Precision=1.0000, Recall=1.0000, F1=1.0000
#
# === Fold 5 ===
# Precision: 0.9939, Recall: 0.9940, Accuracy: 0.9940, F1 Score: 0.9939
#
# === 5-Fold Validation Summary ===
# Avg Precision: 0.9753
# Avg Recall: 0.9752
# Avg Accuracy: 0.9750
# Avg F1 Score: 0.9749
# Best Fold: 5 with F1 Score: 0.9939
#
# === Final Test Fold (Fold 6) Evaluation ===
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 715ms/step
# [[56  0  0]
#  [ 0 54  0]
#  [ 0  0 57]]
# Test Accuracy:  1.0
# Test Precision: 1.0
# Test Recall:    1.0
# Test F1 Score:  1.0

# %% [markdown]
# (2) Training by using CNN via keypoints

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Set random seed for reproducibility
tf.keras.utils.set_random_seed(492)

# Load data
def import_data():
    data = pd.read_csv('mergedshuffledPlankV2keypoints.csv')
    x = data.iloc[:, :-1].values
    y = data['correct'].astype(int).values
    y = np.searchsorted(np.unique(y), y)

    scaler = MinMaxScaler()
    x = scaler.fit_transform(x)
    return x, y

def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Main
x, y = import_data()
num_classes = len(np.unique(y))

# Create 6 folds
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)
folds = list(skf.split(x, y))
train_val_folds = folds[:5]
test_fold = folds[5]

class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights = {i: class_weights[i] for i in range(len(class_weights))}

best_model_path = "best_cnn_model_plank.keras"
best_fold, best_f1 = None, -1
best_model = None
precision_list, recall_list, accuracy_list, f1_list = [], [], [], []

# Train on folds 1–5
for fold_index, (train_index, val_index) in enumerate(train_val_folds, start=1):
    x_train, x_val = x[train_index], x[val_index]
    y_train, y_val = y[train_index], y[val_index]

    x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
    x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

    print(f"\nFold {fold_index} Class Distribution:")
    print(pd.Series(y_val).value_counts())

    model = create_cnn_model(input_shape=(x_train.shape[1], x_train.shape[2]), num_classes=num_classes)
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    model.fit(
        x_train, y_train, epochs=30, batch_size=32,
        validation_data=(x_val, y_val),
        verbose=1, class_weight=class_weights, callbacks=[early_stop]
    )

    predictions = np.argmax(model.predict(x_val), axis=1)
    precision = precision_score(y_val, predictions, average='macro', zero_division=0)
    recall = recall_score(y_val, predictions, average='macro', zero_division=0)
    accuracy = accuracy_score(y_val, predictions)
    f1 = f1_score(y_val, predictions, average='macro', zero_division=0)

    print(f"Fold {fold_index} Confusion Matrix:")
    print(confusion_matrix(y_val, predictions))

    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    f1_list.append(f1)

    print(f"\n=== Fold {fold_index} ===")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")

    if f1 > best_f1:
        best_f1 = f1
        best_fold = fold_index
        best_model = model


print("\n=== 5-Fold Validation Summary ===")
print(f"Avg Precision: {np.mean(precision_list):.4f}")
print(f"Avg Recall: {np.mean(recall_list):.4f}")
print(f"Avg Accuracy: {np.mean(accuracy_list):.4f}")
print(f"Avg F1 Score: {np.mean(f1_list):.4f}")
print(f"Best Fold: {best_fold} with F1 Score: {best_f1:.4f}")

# Evaluate on held-out Fold 6
test_index = test_fold[1]
x_test, y_test = x[test_index], y[test_index]
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

test_preds = np.argmax(best_model.predict(x_test), axis=1)
test_accuracy = accuracy_score(y_test, test_preds)
test_f1 = f1_score(y_test, test_preds, average='macro')
test_precision = precision_score(y_test, test_preds, average='macro', zero_division=0)
test_recall = recall_score(y_test, test_preds, average='macro', zero_division=0)

print("\n=== Final Test Fold (Fold 6) Evaluation ===")
print(confusion_matrix(y_test, test_preds))
print(f"Test Accuracy:  {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall:    {test_recall:.4f}")
print(f"Test F1 Score:  {test_f1:.4f}")
# Out:
# Fold 1 Class Distribution:
# 2    57
# 0    54
# 1    52
# Name: count, dtype: int64
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3481 - loss: 1.0982 - val_accuracy: 0.4969 - val_loss: 1.0820
# Epoch 2/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4809 - loss: 1.0735 - val_accuracy: 0.6380 - val_loss: 1.0496
# Epoch 3/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5892 - loss: 1.0236 - val_accuracy: 0.6687 - val_loss: 0.9710
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6190 - loss: 0.9422 - val_accuracy: 0.7975 - val_loss: 0.8436
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6939 - loss: 0.8189 - val_accuracy: 0.8896 - val_loss: 0.6711
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7630 - loss: 0.6877 - val_accuracy: 0.9264 - val_loss: 0.5279
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8005 - loss: 0.5618 - val_accuracy: 0.9509 - val_loss: 0.4098
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8096 - loss: 0.4861 - val_accuracy: 0.9448 - val_loss: 0.3366
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8563 - loss: 0.4323 - val_accuracy: 0.9693 - val_loss: 0.2750
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8766 - loss: 0.3479 - val_accuracy: 0.9632 - val_loss: 0.2334
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9091 - loss: 0.2978 - val_accuracy: 0.9632 - val_loss: 0.1965
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9096 - loss: 0.2818 - val_accuracy: 0.9755 - val_loss: 0.1653
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9423 
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6721 - loss: 0.8750 - val_accuracy: 0.8765 - val_loss: 0.6892
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7950 - loss: 0.6995 - val_accuracy: 0.9012 - val_loss: 0.5324
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8488 - loss: 0.5447 - val_accuracy: 0.9630 - val_loss: 0.3974
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8880 - loss: 0.4306 - val_accuracy: 0.9753 - val_loss: 0.2911
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9219 - loss: 0.3352 - val_accuracy: 0.9691 - val_loss: 0.2319
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9207 - loss: 0.2858 - val_accuracy: 0.9938 - val_loss: 0.1681
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9327 - loss: 0.2351 - val_accuracy: 0.9630 - val_loss: 0.1607
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9561 - loss: 0.1925 - val_accuracy: 1.0000 - val_loss: 0.1070
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9701 - loss: 0.1598 - val_accuracy: 0.9753 - val_loss: 0.1000
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9589 - loss: 0.1417 - val_accuracy: 1.0000 - val_loss: 0.0736
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9762 - loss: 0.1205 - val_accuracy: 1.0000 - val_loss: 0.0623
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9829 - loss: 0.0916 - val_accuracy: 0.9938 - val_loss: 0.0601
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9752 - loss: 0.0999 - val_accuracy: 0.9938 - val_loss: 0.0591
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9796 - loss: 0.0844 - val_accuracy: 1.0000 - val_loss: 0.0455
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9821 - loss: 0.0774 - val_accuracy: 1.0000 - val_loss: 0.0396
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9834 - loss: 0.0710 - val_accuracy: 0.9691 - val_loss: 0.0608
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.0283
# Epoch 21/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0605 - val_accuracy: 0.9938 - val_loss: 0.0364
# Epoch 22/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9847 - loss: 0.0596 - val_accuracy: 1.0000 - val_loss: 0.0347
# Epoch 23/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9851 - loss: 0.0628 - val_accuracy: 1.0000 - val_loss: 0.0271
# Epoch 24/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9936 - loss: 0.0507 - val_accuracy: 1.0000 - val_loss: 0.0302
# Epoch 25/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9894 - loss: 0.0501 - val_accuracy: 0.9691 - val_loss: 0.0513
# Epoch 26/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9810 - loss: 0.0575 - val_accuracy: 0.9938 - val_loss: 0.0335
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Fold 5 Confusion Matrix:
# [[53  0  0]
#  [ 0 51  0]
#  [ 0  0 58]]
#
# === Fold 5 ===
# Precision: 1.0000, Recall: 1.0000, Accuracy: 1.0000, F1 Score: 1.0000
#
# === 5-Fold Validation Summary ===
# Avg Precision: 0.9901
# Avg Recall: 0.9902
# Avg Accuracy: 0.9902
# Avg F1 Score: 0.9901
# Best Fold: 5 with F1 Score: 1.0000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# === Final Test Fold (Fold 6) Evaluation ===
# [[53  0  0]
#  [ 0 51  0]
#  [ 0  0 58]]
# Test Accuracy:  1.0000
# Test Precision: 1.0000
# Test Recall:    1.0000
# Test F1 Score:  1.0000

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Set random seed for reproducibility
tf.keras.utils.set_random_seed(492)

# Load and return features and labels
def import_data():
    data = pd.read_csv('mergedshuffledPlankV2keypoints.csv')
    x = data.iloc[:, :-1].values
    y = data['correct'].astype(int).values
    y = np.searchsorted(np.unique(y), y)  # encode labels to 0..n_classes-1
    return x, y

def create_cnn_lstm_model(input_shape, num_classes):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Main script
x, y = import_data()
num_classes = len(np.unique(y))

# Prepare 6 stratified folds
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)
folds = list(skf.split(x, y))
train_val_folds = folds[:5]
test_fold = folds[5]

best_f1 = -1
best_fold = None
best_model = None
best_scaler = None

precision_list, recall_list, accuracy_list, f1_list = [], [], [], []

for fold_index, (train_index, val_index) in enumerate(train_val_folds, start=1):
    x_train_raw, x_val_raw = x[train_index], x[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Scale features (fit scaler only on train fold)
    scaler = MinMaxScaler()
    x_train = scaler.fit_transform(x_train_raw)
    x_val = scaler.transform(x_val_raw)

    # Reshape for Conv1D input: (samples, time_steps, features=1)
    x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
    x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

    # Compute class weights for imbalance handling
    class_weights_arr = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
    class_weights = {i: class_weights_arr[i] for i in range(len(class_weights_arr))}

    print(f"\n=== Fold {fold_index} ===")
    print("Class distribution (val):", pd.Series(y_val).value_counts().to_dict())

    model = create_cnn_lstm_model(input_shape=(x_train.shape[1], x_train.shape[2]), num_classes=num_classes)
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    model.fit(
        x_train, y_train,
        epochs=30,
        batch_size=32,
        validation_data=(x_val, y_val),
        verbose=1,
        class_weight=class_weights,
        callbacks=[early_stop]
    )

    preds = np.argmax(model.predict(x_val), axis=1)
    precision = precision_score(y_val, preds, average='macro', zero_division=0)
    recall = recall_score(y_val, preds, average='macro', zero_division=0)
    accuracy = accuracy_score(y_val, preds)
    f1 = f1_score(y_val, preds, average='macro', zero_division=0)

    print("Confusion Matrix:")
    print(confusion_matrix(y_val, preds))
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")

    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    f1_list.append(f1)

    # Save best model and scaler in memory (not yet saved to disk)
    if f1 > best_f1:
        best_f1 = f1
        best_fold = fold_index
        best_model = model
        best_scaler = scaler

print("\n=== 5-Fold Cross-Validation Summary ===")
print(f"Avg Precision: {np.mean(precision_list):.4f}")
print(f"Avg Recall:    {np.mean(recall_list):.4f}")
print(f"Avg Accuracy:  {np.mean(accuracy_list):.4f}")
print(f"Avg F1 Score:  {np.mean(f1_list):.4f}")
print(f"Best Fold: {best_fold} with F1 Score: {best_f1:.4f}")

# Save best model to disk
best_model_path = 'best_cnn_model_plank.keras'
if best_model is not None:
    best_model.save(best_model_path)
    print(f"Saved best model from Fold {best_fold} with F1 Score: {best_f1:.4f}")

# Load best model for testing on fold 6
final_model = load_model(best_model_path)

test_index = test_fold[1]
x_test_raw, y_test = x[test_index], y[test_index]

# Scale test set using best fold scaler
x_test = best_scaler.transform(x_test_raw)
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

test_preds = np.argmax(final_model.predict(x_test), axis=1)
test_precision = precision_score(y_test, test_preds, average='macro', zero_division=0)
test_recall = recall_score(y_test, test_preds, average='macro', zero_division=0)
test_accuracy = accuracy_score(y_test, test_preds)
test_f1 = f1_score(y_test, test_preds, average='macro', zero_division=0)

print("\n=== Final Test Fold (Fold 6) Evaluation ===")
print(confusion_matrix(y_test, test_preds))
print(f"Test Accuracy:  {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall:    {test_recall:.4f}")
print(f"Test F1 Score:  {test_f1:.4f}")
# Out:
# === Fold 1 ===
# Class distribution (val): {2: 57, 0: 54, 1: 52}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.3420 - loss: 1.0988 - val_accuracy: 0.5153 - val_loss: 1.0818
# Epoch 2/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4619 - loss: 1.0734 - val_accuracy: 0.6564 - val_loss: 1.0470
# Epoch 3/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5771 - loss: 1.0193 - val_accuracy: 0.6871 - val_loss: 0.9621
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6341 - loss: 0.9307 - val_accuracy: 0.8160 - val_loss: 0.8202
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6895 - loss: 0.7969 - val_accuracy: 0.8896 - val_loss: 0.6381
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7764 - loss: 0.6566 - val_accuracy: 0.9325 - val_loss: 0.4880
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8238 - loss: 0.5247 - val_accuracy: 0.9509 - val_loss: 0.3727
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8380 - loss: 0.4454 - val_accuracy: 0.9509 - val_loss: 0.2968
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8546 - loss: 0.3940 - val_accuracy: 0.9755 - val_loss: 0.2346
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9120 - loss: 0.3066 - val_accuracy: 0.9632 - val_loss: 0.2001
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9091 - loss: 0.2622 - val_accuracy: 0.9571 - val_loss: 0.1714
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9238 - loss: 0.2740 - val_accuracy: 1.0000 - val_loss: 0.1591
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9368 - loss: 0.2314 - val_accuracy: 0.9630 - val_loss: 0.1533
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9529 - loss: 0.1880 - val_accuracy: 1.0000 - val_loss: 0.1074
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9643 - loss: 0.1602 - val_accuracy: 0.9753 - val_loss: 0.1038
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9542 - loss: 0.1470 - val_accuracy: 1.0000 - val_loss: 0.0731
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9697 - loss: 0.1231 - val_accuracy: 1.0000 - val_loss: 0.0625
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9772 - loss: 0.0995 - val_accuracy: 0.9938 - val_loss: 0.0565
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9754 - loss: 0.1000 - val_accuracy: 1.0000 - val_loss: 0.0483
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9819 - loss: 0.0833 - val_accuracy: 1.0000 - val_loss: 0.0439
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9823 - loss: 0.0800 - val_accuracy: 1.0000 - val_loss: 0.0319
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9761 - loss: 0.0766 - val_accuracy: 0.9877 - val_loss: 0.0440
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9823 - loss: 0.0783 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 21/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.0580 - val_accuracy: 1.0000 - val_loss: 0.0283
# Epoch 22/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9830 - loss: 0.0604 - val_accuracy: 1.0000 - val_loss: 0.0314
# Epoch 23/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9863 - loss: 0.0603 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 24/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0535 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 25/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0535 - val_accuracy: 0.9691 - val_loss: 0.0699
# Epoch 26/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9776 - loss: 0.0680 - val_accuracy: 0.9938 - val_loss: 0.0305
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Confusion Matrix:
# [[53  0  0]
#  [ 0 51  0]
#  [ 0  0 58]]
# Precision: 1.0000, Recall: 1.0000, Accuracy: 1.0000, F1 Score: 1.0000
#
# === 5-Fold Cross-Validation Summary ===
# Avg Precision: 0.9927
# Avg Recall:    0.9927
# Avg Accuracy:  0.9926
# Avg F1 Score:  0.9926
# Best Fold: 5 with F1 Score: 1.0000
# Saved best model from Fold 5 with F1 Score: 1.0000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# === Final Test Fold (Fold 6) Evaluation ===
# [[53  0  0]
#  [ 0 51  0]
#  [ 0  0 58]]
# Test Accuracy:  1.0000
# Test Precision: 1.0000
# Test Recall:    1.0000
# Test F1 Score:  1.0000

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# Set random seed for reproducibility
tf.keras.utils.set_random_seed(492)

# Load data
def import_data():
    data = pd.read_csv('mergedshuffledPlankV2keypoints.csv')
    x = data.iloc[:, :-1].values
    y = data['correct'].astype(int).values
    y = np.searchsorted(np.unique(y), y)

    scaler = MinMaxScaler()
    x = scaler.fit_transform(x)
    return x, y

def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Main
x, y = import_data()
num_classes = len(np.unique(y))

# Create 6 folds
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)
folds = list(skf.split(x, y))
train_val_folds = folds[:5]
test_fold = folds[5]

# Class weights from full dataset
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights = {i: class_weights[i] for i in range(len(class_weights))}

best_model_path = "best_cnn_model_plank.keras"
best_fold, best_f1 = None, -1
best_model = None
best_scaler = None
precision_list, recall_list, accuracy_list, f1_list = [], [], [], []

# Train on folds 1–5
for fold_index, (train_index, val_index) in enumerate(train_val_folds, start=1):
    x_train, x_val = x[train_index], x[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Create and fit scaler for this fold
    scaler = MinMaxScaler()
    x_train = scaler.fit_transform(x_train)
    x_val = scaler.transform(x_val)

    x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
    x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

    print(f"\nFold {fold_index} Class Distribution:")
    print(pd.Series(y_val).value_counts())

    model = create_cnn_model(input_shape=(x_train.shape[1], x_train.shape[2]), num_classes=num_classes)
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    model.fit(
        x_train, y_train, epochs=30, batch_size=32,
        validation_data=(x_val, y_val),
        verbose=1, class_weight=class_weights, callbacks=[early_stop]
    )

    predictions = np.argmax(model.predict(x_val), axis=1)
    precision = precision_score(y_val, predictions, average='macro', zero_division=0)
    recall = recall_score(y_val, predictions, average='macro', zero_division=0)
    accuracy = accuracy_score(y_val, predictions)
    f1 = f1_score(y_val, predictions, average='macro', zero_division=0)

    print(f"Fold {fold_index} Confusion Matrix:")
    print(confusion_matrix(y_val, predictions))

    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    f1_list.append(f1)

    print(f"\n=== Fold {fold_index} ===")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")

    if f1 > best_f1:
        best_f1 = f1
        best_fold = fold_index
        best_model = model
        best_scaler = scaler
        # Save the best model and scaler
        model.save('best_model.keras')
        joblib.dump(scaler, 'best_scaler.pkl')
        print(f"Saved best model and scaler from Fold {fold_index} with F1 Score: {f1:.4f}")

print("\n=== 5-Fold Validation Summary ===")
print(f"Avg Precision: {np.mean(precision_list):.4f}")
print(f"Avg Recall: {np.mean(recall_list):.4f}")
print(f"Avg Accuracy: {np.mean(accuracy_list):.4f}")
print(f"Avg F1 Score: {np.mean(f1_list):.4f}")
print(f"Best Fold: {best_fold} with F1 Score: {best_f1:.4f}")

# Evaluate on held-out Fold 6
test_index = test_fold[1]
x_test, y_test = x[test_index], y[test_index]
x_test = best_scaler.transform(x_test)  # Use best scaler to transform test data
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

test_preds = np.argmax(best_model.predict(x_test), axis=1)
test_accuracy = accuracy_score(y_test, test_preds)
test_f1 = f1_score(y_test, test_preds, average='macro')
test_precision = precision_score(y_test, test_preds, average='macro', zero_division=0)
test_recall = recall_score(y_test, test_preds, average='macro', zero_division=0)

print("\n=== Final Test Fold (Fold 6) Evaluation ===")
print(confusion_matrix(y_test, test_preds))
print(f"Test Accuracy:  {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall:    {test_recall:.4f}")
print(f"Test F1 Score:  {test_f1:.4f}")

print(f"\n=== Best Model Summary ===")
print(f"Best model is from Fold {best_fold} with F1 Score: {best_f1:.4f}")
# Out:
# Fold 1 Class Distribution:
# 2    57
# 0    54
# 1    52
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.3480 - loss: 1.0989 - val_accuracy: 0.5460 - val_loss: 1.0818
# Epoch 2/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4683 - loss: 1.0724 - val_accuracy: 0.6135 - val_loss: 1.0400
# Epoch 3/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5980 - loss: 1.0083 - val_accuracy: 0.7055 - val_loss: 0.9419
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6436 - loss: 0.9107 - val_accuracy: 0.8650 - val_loss: 0.7884
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7143 - loss: 0.7681 - val_accuracy: 0.9202 - val_loss: 0.6111
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7844 - loss: 0.6331 - val_accuracy: 0.9202 - val_loss: 0.4793
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8278 - loss: 0.5170 - val_accuracy: 0.9571 - val_loss: 0.3713
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8537 - loss: 0.4360 - val_accuracy: 0.9571 - val_loss: 0.3205
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8658 - loss: 0.3918 - val_accuracy: 0.9693 - val_loss: 0.2582
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9046 - loss: 0.3255 - val_accuracy: 0.9632 - val_loss: 0.2206
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9254 - loss: 0.2802 - val_accuracy: 0.9693 - val_loss: 0.1765
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9184 - loss: 0.2666 - val_accuracy: 0.9693 - val_loss: 0.1507
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9307 - loss: 0.2141 - val_accuracy: 0.9755 - val_loss: 0.1230
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9295 - loss: 0.2049 - val_accuracy: 0.9693 - val_loss: 0.1176
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9577 - loss: 0.1710 - val_accuracy: 0.9755 - val_loss: 0.1031
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9660 - loss: 0.1635 - val_accuracy: 0.9693 - val_loss: 0.0907
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9494 - loss: 0.1410 - val_accuracy: 0.9877 - val_loss: 0.0783
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9505 - loss: 0.1469 - val_accuracy: 0.9755 - val_loss: 0.0860
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9802 - loss: 0.1117 - val_accuracy: 0.9816 - val_loss: 0.0665
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9823 - loss: 0
30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8420 - loss: 0.5241 - val_accuracy: 0.9568 - val_loss: 0.3793
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8941 - loss: 0.4066 - val_accuracy: 0.9815 - val_loss: 0.2724
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9386 - loss: 0.3137 - val_accuracy: 0.9691 - val_loss: 0.2147
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9235 - loss: 0.2720 - val_accuracy: 0.9938 - val_loss: 0.1577
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9417 - loss: 0.2248 - val_accuracy: 0.9630 - val_loss: 0.1496
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9544 - loss: 0.1857 - val_accuracy: 1.0000 - val_loss: 0.1045
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9666 - loss: 0.1540 - val_accuracy: 0.9753 - val_loss: 0.0981
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9552 - loss: 0.1406 - val_accuracy: 1.0000 - val_loss: 0.0725
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9726 - loss: 0.1199 - val_accuracy: 1.0000 - val_loss: 0.0614
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9791 - loss: 0.0947 - val_accuracy: 0.9938 - val_loss: 0.0590
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9770 - loss: 0.0962 - val_accuracy: 1.0000 - val_loss: 0.0495
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9810 - loss: 0.0801 - val_accuracy: 0.9938 - val_loss: 0.0457
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9788 - loss: 0.0778 - val_accuracy: 1.0000 - val_loss: 0.0328
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9802 - loss: 0.0709 - val_accuracy: 0.9753 - val_loss: 0.0558
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9771 - loss: 0.0833 - val_accuracy: 1.0000 - val_loss: 0.0247
# Epoch 21/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0527 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 22/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9821 - loss: 0.0584 - val_accuracy: 0.9938 - val_loss: 0.0324
# Epoch 23/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9860 - loss: 0.0599 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 24/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9880 - loss: 0.0511 - val_accuracy: 1.0000 - val_loss: 0.0289
# Epoch 25/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.0500 - val_accuracy: 0.9753 - val_loss: 0.0595
# Epoch 26/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9770 - loss: 0.0597 - val_accuracy: 0.9938 - val_loss: 0.0341
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Fold 5 Confusion Matrix:
# [[53  0  0]
#  [ 0 51  0]
#  [ 0  0 58]]
#
# === Fold 5 ===
# Precision: 1.0000, Recall: 1.0000, Accuracy: 1.0000, F1 Score: 1.0000
# Saved best model and scaler from Fold 5 with F1 Score: 1.0000
#
# === 5-Fold Validation Summary ===
# Avg Precision: 0.9927
# Avg Recall: 0.9927
# Avg Accuracy: 0.9926
# Avg F1 Score: 0.9926
# Best Fold: 5 with F1 Score: 1.0000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# === Final Test Fold (Fold 6) Evaluation ===
# [[53  0  0]
#  [ 0 51  0]
#  [ 0  0 58]]
# Test Accuracy:  1.0000
# Test Precision: 1.0000
# Test Recall:    1.0000
# Test F1 Score:  1.0000
#
# === Best Model Summary ===
# Best model is from Fold 5 with F1 Score: 1.0000

# %% [markdown]
# (3)Training model by adding augmentation data

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, BatchNormalization, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Set random seed
tf.keras.utils.set_random_seed(492)

# Load data
def import_data():
    data = pd.read_csv('mergedshuffledPlankV2keypoints.csv')
    x = data.iloc[:, :-1].values
    y = data['correct'].astype(int).values
    y = np.searchsorted(np.unique(y), y)
    scaler = MinMaxScaler()
    x = scaler.fit_transform(x)
    return x, y

def balance_data(x, y):
    smote = SMOTE(sampling_strategy='auto', random_state=42)
    x_resampled, y_resampled = smote.fit_resample(x, y)
    print("Balanced class distribution:")
    print(pd.Series(y_resampled).value_counts())
    return x_resampled, y_resampled

def augment_data(x, noise_factor=0.05):
    noise = np.random.normal(loc=0.0, scale=noise_factor, size=x.shape)
    return x + noise

def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Load and prepare data
x, y = import_data()
x, y = balance_data(x, y)
x = augment_data(x, noise_factor=0.05)
num_classes = len(np.unique(y))

# Create 6 folds
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)
folds = list(skf.split(x, y))
train_val_folds = folds[:5]
test_fold = folds[5]

# Class weights
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights = {i: class_weights[i] for i in range(len(class_weights))}

# Cross-validation
best_model_path = "best_cnn_model.keras"
best_model = None
best_fold, best_f1 = None, -1
precision_list, recall_list, accuracy_list, f1_list = [], [], [], []

#Train 5 folds
for fold_index, (train_idx, val_idx) in enumerate(train_val_folds, start=1):
    x_train, x_val = x[train_idx], x[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
    x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

    print(f"\nFold {fold_index} Class Distribution:")
    print(pd.Series(y_val).value_counts())

    model = create_cnn_model(input_shape=(x_train.shape[1], x_train.shape[2]), num_classes=num_classes)
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    model.fit(
        x_train, y_train, epochs=30, batch_size=32,
        validation_data=(x_val, y_val),
        verbose=1, class_weight=class_weights, callbacks=[early_stop]
    )

    predictions = np.argmax(model.predict(x_val), axis=1)
    precision = precision_score(y_val, predictions, average='macro', zero_division=0)
    recall = recall_score(y_val, predictions, average='macro', zero_division=0)
    accuracy = accuracy_score(y_val, predictions)
    f1 = f1_score(y_val, predictions, average='macro', zero_division=0)

    print(f"Fold {fold_index} Confusion Matrix:")
    print(confusion_matrix(y_val, predictions))

    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    f1_list.append(f1)

    print(f"\n=== Fold {fold_index} ===")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")

    if f1 > best_f1:
        best_f1 = f1
        best_fold = fold_index
        best_model = model  # Save best model


print("\n=== 5-Fold Validation Summary ===")
print(f"Avg Precision: {np.mean(precision_list):.4f}")
print(f"Avg Recall:    {np.mean(recall_list):.4f}")
print(f"Avg Accuracy:  {np.mean(accuracy_list):.4f}")
print(f"Avg F1 Score:  {np.mean(f1_list):.4f}")
print(f"Best Fold: {best_fold} with F1 Score: {best_f1:.4f}")

# Evaluate on held-out Fold 6
test_idx = test_fold[1]
x_test, y_test = x[test_idx], y[test_idx]
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

test_preds = np.argmax(best_model.predict(x_test), axis=1)
test_accuracy = accuracy_score(y_test, test_preds)
test_f1 = f1_score(y_test, test_preds, average='macro')
test_precision = precision_score(y_test, test_preds, average='macro', zero_division=0)
test_recall = recall_score(y_test, test_preds, average='macro', zero_division=0)

print("\n=== Final Test Fold (Fold 6) Evaluation ===")
print(confusion_matrix(y_test, test_preds))
print(f"Test Accuracy:  {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall:    {test_recall:.4f}")
print(f"Test F1 Score:  {test_f1:.4f}")

# Save best model
best_model.save(best_model_path)
print(f"\nBest model saved to: {best_model_path}")
# Out:
# Balanced class distribution:
# 1    346
# 2    346
# 0    346
# Name: count, dtype: int64
#
# Fold 1 Class Distribution:
# 1    58
# 2    58
# 0    57
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.3426 - loss: 1.0962 - val_accuracy: 0.4451 - val_loss: 1.0801
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4064 - loss: 1.0761 - val_accuracy: 0.6532 - val_loss: 1.0404
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5029 - loss: 1.0335 - val_accuracy: 0.6763 - val_loss: 0.9481
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5778 - loss: 0.9541 - val_accuracy: 0.7803 - val_loss: 0.8070
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6996 - loss: 0.8126 - val_accuracy: 0.7861 - val_loss: 0.6624
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.